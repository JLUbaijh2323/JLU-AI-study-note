# %% [markdown]
# ## 你去参加“谁能成为百万富翁”电视答题节目
# ## 节目组给出了一道100w美金的题目，题目有A，B，C，D，4个选项，其中只有一个正确选项
# ## 这道题目你不会，这时你选择随便蒙一个答案 B
# ## 当你选择了B答案后，主持人告诉你：
# ## 在你没有选的选项A、C、D中其中选项C是错误选项，并询问你
# ## 是否需要更换答案。
# ### 首先请你进行计算判断你是否更换答案
# ### 再编写一个程序，模拟题目所给出的场景，进行实验，进行多次实验后记录实验结果，证明你的计算结果。

# %%
import random

times = 1000
delay = ['a','b','c','d']
def test(times):
